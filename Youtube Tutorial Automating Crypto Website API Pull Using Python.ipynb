# %% [markdown]
# * Automating Crypto Website API Pull Using Python

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
# The parameters dictionary contains the parameters for the API request.
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
#The headers dictionary contains the headers for the API request.
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}
#A Session object allows you to persist certain parameters across requests.
session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11621
# 1    1027      Ethereum    ETH      ethereum              9184
# 2     825   Tether USDt   USDT        tether             93461
# 3    1839           BNB    BNB           bnb              2203
# 4    5426        Solana    SOL        solana               712
# 5    3408          USDC   USDC      usd-coin             21298
# 6      52           XRP    XRP           xrp              1359
# 7      74      Dogecoin   DOGE      dogecoin              1032
# 8   11419       Toncoin    TON       toncoin               487
# 9    2010       Cardano    ADA       cardano              1219
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               759
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               797
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               908
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2021-08-26T13:40:22.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.973506e+07  1.973506e+07            False       NaN         1
# 1         1.202552e+08  1.202552e+08             True       NaN         2
# 2         1.145427e+11  1.170681e+11             True       NaN         3
# 3         1.459372e+08  1.459372e+08            False       NaN         4
# 4         4.653870e+08  5.814996e+08             True       NaN         5
# 5         3.306437e+10  3.306437e+10            False       NaN         6
# 6         5.599928e+10  9.998739e+10            False       NaN         7
# 7         1.453829e+11  1.453829e+11             True       NaN         8
# 8         2.518066e+09  5.109950e+09             True       NaN         9
# 9         3.591667e+10  3.710300e+10            False       NaN        10
# 10        8.702507e+10  8.702512e+10             True       NaN        11
# 11        3.950300e+08  4.443764e+08            False       NaN        12
# 12        5.892705e+14  5.895191e+14            False       NaN        13
# 13        1.476364e+09  1.476364e+09             True       NaN        14
# 14        1.974197e+07  1.974197e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       3.414167e+09              2.094370e+10      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              8.963532e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                      1.476364e+09              7.631309e+09      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-08-03T15:12:00.000Z     62012.268692          3.452551e+10
# 1   2024-08-03T15:11:00.000Z      3000.726450          1.819065e+10
# 2   2024-08-03T15:11:00.000Z         0.999362          6.313252e+10
# 3   2024-08-03T15:11:00.000Z       542.920586          1.911975e+09
# 4   2024-08-03T15:11:00.000Z       151.664636          3.797838e+09
# 5   2024-08-03T15:11:00.000Z         0.999998          6.658483e+09
# 6   2024-08-03T15:12:00.000Z         0.567465          1.361268e+09
# 7   2024-08-03T15:12:00.000Z         0.113489          7.686643e+08
# 8   2024-08-03T15:11:00.000Z         6.134353          2.537623e+08
# 9   2024-08-03T15:11:00.000Z         0.368530          3.019137e+08
# 10  2024-08-03T15:11:00.000Z         0.125085          3.207938e+08
# 11  2024-08-03T15:11:00.000Z        23.876232          2.682389e+08
# 12  2024-08-03T15:11:00.000Z         0.000015          2.335171e+08
# 13  2024-08-03T15:12:00.000Z         5.168990          1.385484e+08
# 14  2024-08-03T15:11:00.000Z       377.425887          3.190074e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -22.4752                     0.158289
# 1                       -9.9122                    -0.055720
# 2                       -8.9184                    -0.002852
# 3                       -7.2667                     0.069792
# 4                      -14.4639                    -0.304020
# 5                      -16.7166                    -0.001762
# 6                      -30.3689                    -0.646163
# 7                      -13.5297                    -0.097477
# 8                       -5.6209                    -0.129420
# 9                      -23.8514                    -0.302105
# 10                      -5.0763                    -0.011213
# 11                     -21.1877                    -0.597664
# 12                     -16.9433                    -0.123508
# 13                     -23.9983                    -0.243308
# 14                      -3.5303                    -0.448251
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -1.169548                   -10.040742
# 1                      -0.450701                    -9.038925
# 2                       0.036154                    -0.079401
# 3                      -1.568655                    -7.533262
# 4                      -2.887334                   -17.578373
# 5                       0.000229                    -0.004048
# 6                       2.364934                    -5.378526
# 7                       1.326849                   -15.910550
# 8                      -4.698493                    -8.213808
# 9                       1.731776                   -12.983630
# 10                     -0.145044                    -8.945541
# 11                      0.613024                   -18.171043
# 12                     -0.896325                   -14.431415
# 13                      2.342798                   -11.773188
# 14                     -3.920710                    -3.807526
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       7.823586                    -11.075995
# 1                      -3.841242                    -20.616527
# 2                       0.010582                     -0.060335
# 3                       4.151273                    -17.864230
# 4                      12.723835                     -8.541146
# 5                       0.001383                     -0.006344
# 6                      27.415293                      7.801441
# 7                       4.437848                    -28.722958
# 8                     -14.638390                    -12.153100
# 9                      -3.558615                    -19.392781
# 10                     -0.725065                      9.646533
# 11                     -5.726163                    -32.284473
# 12                     -1.321242                    -38.667781
# 13                    -10.133697                    -27.323054
# 14                     10.431855                    -19.620316
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -3.205502          1.223816e+12
# 1                      -4.703027          3.608529e+11
# 2                      -0.073940          1.144696e+11
# 3                      -8.168873          7.923231e+10
# 4                       2.967763          7.058275e+10
# 5                      -0.000287          3.306431e+10
# 6                       7.181570          3.177761e+10
# 7                     -29.276073          1.649938e+10
# 8                       4.453552          1.544671e+10
# 9                     -20.120590          1.323637e+10
# 10                      3.179776          1.088551e+10
# 11                    -35.727714          9.431828e+09
# 12                    -40.561981          8.685598e+09
# 13                    -27.970233          7.631309e+09
# 14                    -19.007592          7.451129e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          55.4794                        1.302258e+12
# 1                          16.3606                        3.608529e+11
# 2                           5.1899                        1.169934e+11
# 3                           3.5923                        7.923231e+10
# 4                           3.2001                        8.819293e+10
# 5                           1.4991                        3.306431e+10
# 6                           1.4399                        5.674645e+10
# 7                           0.7476                        1.649938e+10
# 8                           0.7003                        3.134624e+10
# 9                           0.6001                        1.658385e+10
# 10                          0.4935                        1.088552e+10
# 11                          0.4276                        1.708938e+10
# 12                          0.3938                        8.689262e+09
# 13                          0.3458                        7.631309e+09
# 14                          0.3378                        7.925944e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-08-03T15:12:00.000Z          NaN           NaN
# 1           None  2024-08-03T15:11:00.000Z          NaN           NaN
# 2           None  2024-08-03T15:11:00.000Z       1027.0      Ethereum
# 3           None  2024-08-03T15:11:00.000Z          NaN           NaN
# 4           None  2024-08-03T15:11:00.000Z          NaN           NaN
# 5           None  2024-08-03T15:11:00.000Z       1027.0      Ethereum
# 6           None  2024-08-03T15:12:00.000Z          NaN           NaN
# 7           None  2024-08-03T15:12:00.000Z          NaN           NaN
# 8           None  2024-08-03T15:11:00.000Z          NaN           NaN
# 9           None  2024-08-03T15:11:00.000Z          NaN           NaN
# 10          None  2024-08-03T15:11:00.000Z          NaN           NaN
# 11          None  2024-08-03T15:11:00.000Z          NaN           NaN
# 12          None  2024-08-03T15:11:00.000Z       1027.0      Ethereum
# 13          None  2024-08-03T15:12:00.000Z          NaN           NaN
# 14          None  2024-08-03T15:11:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-08-03 15:14:27.811247
# 1  2024-08-03 15:14:27.811247
# 2  2024-08-03 15:14:27.811247
# 3  2024-08-03 15:14:27.811247
# 4  2024-08-03 15:14:27.811247
# 5  2024-08-03 15:14:27.811247
# 6  2024-08-03 15:14:27.811247
# 7  2024-08-03 15:14:27.811247
# 8  2024-08-03 15:14:27.811247
# 9  2024-08-03 15:14:27.811247
# 10 2024-08-03 15:14:27.811247
# 11 2024-08-03 15:14:27.811247
# 12 2024-08-03 15:14:27.811247
# 13 2024-08-03 15:14:27.811247
# 14 2024-08-03 15:14:27.811247

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    # The parameters dictionary contains the parameters for the API request.
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    #The headers dictionary contains the headers for the API request.
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }
    #A Session object allows you to persist certain parameters across requests.
    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    # here we append the new created data frame to the original data frame.
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)
    
    #save the data into a csv file(the following code is incase we wanna save the data to a csv file and append into it)
    #if not os.path.isfile(r'C:\Users\HP\OneDrive\Desktop\Tutorial\Python Tutorial\2. Automating Crypto Website API Pull Using Python\API.csv'):# this will check if the file existed if not it will creat one.
    #    df.to_csv(r'C:\Users\HP\OneDrive\Desktop\Tutorial\Python Tutorial\2. Automating Crypto Website API Pull Using Python\API.csv', header = 'column_names')
    #else:   
    #   df.to_csv(r'C:\Users\HP\OneDrive\Desktop\Tutorial\Python Tutorial\2. Automating Crypto Website API Pull Using Python\API.csv', mode = 'a', header = False)# a means append, header false means we do not need to append data with headers again.

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)# the for loop will be run each 60 seconds.
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20640/525344096.py in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)# the for loop will be run each 60 seconds.
#       9 exit()
#
# KeyboardInterrupt:

# %%
pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\Tutorial\Python Tutorial\2. Automating Crypto Website API Pull Using Python\API.csv')
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             11621
# 1            1   1027      Ethereum    ETH      ethereum              9184
# 2            2    825   Tether USDt   USDT        tether             93459
# 3            3   1839           BNB    BNB           bnb              2203
# 4            4   5426        Solana    SOL        solana               712
# 5            5   3408          USDC   USDC      usd-coin             21297
# 6            6     52           XRP    XRP           xrp              1359
# 7            7     74      Dogecoin   DOGE      dogecoin              1032
# 8            8  11419       Toncoin    TON       toncoin               487
# 9            9   2010       Cardano    ADA       cardano              1219
# 10          10   1958          TRON    TRX          tron              1006
# 11          11   5805     Avalanche   AVAX     avalanche               759
# 12          12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13          13   6636      Polkadot    DOT  polkadot-new               797
# 14          14   1831  Bitcoin Cash    BCH  bitcoin-cash               908
# 15           0      1       Bitcoin    BTC       bitcoin             11621
# 16           1   1027      Ethereum    ETH      ethereum              9184
# 17           2    825   Tether USDt   USDT        tether             93459
# 18           3   1839           BNB    BNB           bnb              2203
# 19           4   5426        Solana    SOL        solana               712
# 20           5   3408          USDC   USDC      usd-coin             21297
# 21           6     52           XRP    XRP           xrp              1359
# 22           7     74      Dogecoin   DOGE      dogecoin              1032
# 23           8  11419       Toncoin    TON       toncoin               487
# 24           9   2010       Cardano    ADA       cardano              1219
# 25          10   1958          TRON    TRX          tron              1006
# 26          11   5805     Avalanche   AVAX     avalanche               759
# 27          12   5994     Shiba Inu   SHIB     shiba-inu               854
# 28          13   6636      Polkadot    DOT  polkadot-new               797
# 29          14   1831  Bitcoin Cash    BCH  bitcoin-cash               908
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2021-08-26T13:40:22.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2017-07-25T00:00:00.000Z
# 19  2020-04-10T00:00:00.000Z
# 20  2018-10-08T00:00:00.000Z
# 21  2013-08-04T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2021-08-26T13:40:22.000Z
# 24  2017-10-01T00:00:00.000Z
# 25  2017-09-13T00:00:00.000Z
# 26  2020-07-13T00:00:00.000Z
# 27  2020-08-01T00:00:00.000Z
# 28  2020-08-19T00:00:00.000Z
# 29  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'ava...           NaN
# 3   ['marketplace', 'centralized-exchange', 'payme...           NaN
# 4   ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 5   ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 6   ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 7   ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 8   ['pos', 'layer-1', 'ftx-bankruptcy-estate', 'd...           NaN
# 9   ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 10  ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 11  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 12  ['memes', 'ethereum-ecosystem', 'doggone-dogge...           NaN
# 13  ['substrate', 'polkadot', 'binance-chain', 'po...           NaN
# 14  ['mineable', 'pow', 'sha-256', 'marketplace', ...  2.100000e+07
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 17  ['stablecoin', 'asset-backed-stablecoin', 'ava...           NaN
# 18  ['marketplace', 'centralized-exchange', 'payme...           NaN
# 19  ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 20  ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 21  ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 22  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 23  ['pos', 'layer-1', 'ftx-bankruptcy-estate', 'd...           NaN
# 24  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 25  ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 26  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 27  ['memes', 'ethereum-ecosystem', 'doggone-dogge...           NaN
# 28  ['substrate', 'polkadot', 'binance-chain', 'po...           NaN
# 29  ['mineable', 'pow', 'sha-256', 'marketplace', ...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.973502e+07  1.973502e+07            False       NaN         1
# 1         1.202552e+08  1.202552e+08             True       NaN         2
# 2         1.145427e+11  1.170681e+11             True       NaN         3
# 3         1.459372e+08  1.459372e+08            False       NaN         4
# 4         4.653874e+08  5.814999e+08             True       NaN         5
# 5         3.305944e+10  3.305944e+10            False       NaN         6
# 6         5.599928e+10  9.998739e+10            False       NaN         7
# 7         1.453817e+11  1.453817e+11             True       NaN         8
# 8         2.518063e+09  5.109947e+09             True       NaN         9
# 9         3.591667e+10  3.710300e+10            False       NaN        10
# 10        8.702561e+10  8.702562e+10             True       NaN        11
# 11        3.950210e+08  4.443674e+08            False       NaN        12
# 12        5.892705e+14  5.895191e+14            False       NaN        13
# 13        1.476362e+09  1.476362e+09             True       NaN        14
# 14        1.974193e+07  1.974193e+07            False       NaN        15
# 15        1.973502e+07  1.973502e+07            False       NaN         1
# 16        1.202552e+08  1.202552e+08             True       NaN         2
# 17        1.145427e+11  1.170681e+11             True       NaN         3
# 18        1.459372e+08  1.459372e+08            False       NaN         4
# 19        4.653874e+08  5.814999e+08             True       NaN         5
# 20        3.305944e+10  3.305944e+10            False       NaN         6
# 21        5.599928e+10  9.998739e+10            False       NaN         7
# 22        1.453817e+11  1.453817e+11             True       NaN         8
# 23        2.518063e+09  5.109947e+09             True       NaN         9
# 24        3.591667e+10  3.710300e+10            False       NaN        10
# 25        8.702561e+10  8.702562e+10             True       NaN        11
# 26        3.950210e+08  4.443674e+08            False       NaN        12
# 27        5.892705e+14  5.895191e+14            False       NaN        13
# 28        1.476362e+09  1.476362e+09             True       NaN        14
# 29        1.974193e+07  1.974193e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                       3.414167e+09              2.100744e+10        NaN
# 9                                NaN                       NaN        NaN
# 10                      7.165966e+10              8.938329e+09        NaN
# 11                               NaN                       NaN        NaN
# 12                               NaN                       NaN        NaN
# 13                      1.476362e+09              7.627768e+09        NaN
# 14                               NaN                       NaN        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN        NaN
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN        NaN
# 20                               NaN                       NaN        NaN
# 21                               NaN                       NaN        NaN
# 22                               NaN                       NaN        NaN
# 23                      3.414167e+09              2.100376e+10        NaN
# 24                               NaN                       NaN        NaN
# 25                      7.165966e+10              8.942509e+09        NaN
# 26                               NaN                       NaN        NaN
# 27                               NaN                       NaN        NaN
# 28                      1.476362e+09              7.625931e+09        NaN
# 29                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-08-03T13:19:00.000Z     61901.706885          4.055604e+10
# 1   2024-08-03T13:18:00.000Z      3002.666863          2.113151e+10
# 2   2024-08-03T13:18:00.000Z         0.999269          7.157865e+10
# 3   2024-08-03T13:18:00.000Z       541.554760          2.030628e+09
# 4   2024-08-03T13:18:00.000Z       151.817892          4.393061e+09
# 5   2024-08-03T13:18:00.000Z         0.999942          7.703797e+09
# 6   2024-08-03T13:19:00.000Z         0.569136          1.544105e+09
# 7   2024-08-03T13:19:00.000Z         0.113075          8.651596e+08
# 8   2024-08-03T13:18:00.000Z         6.153022          2.955975e+08
# 9   2024-08-03T13:18:00.000Z         0.368959          3.507483e+08
# 10  2024-08-03T13:18:00.000Z         0.124733          3.413629e+08
# 11  2024-08-03T13:18:00.000Z        24.028728          3.150405e+08
# 12  2024-08-03T13:18:00.000Z         0.000015          2.654417e+08
# 13  2024-08-03T13:19:00.000Z         5.166596          1.573775e+08
# 14  2024-08-03T13:18:00.000Z       378.879850          3.446891e+08
# 15  2024-08-03T13:20:00.000Z     61862.800441          4.051036e+10
# 16  2024-08-03T13:19:00.000Z      3003.144958          2.113191e+10
# 17  2024-08-03T13:19:00.000Z         0.999298          7.157662e+10
# 18  2024-08-03T13:19:00.000Z       541.848722          2.030628e+09
# 19  2024-08-03T13:19:00.000Z       151.872396          4.393071e+09
# 20  2024-08-03T13:19:00.000Z         0.999951          7.704146e+09
# 21  2024-08-03T13:20:00.000Z         0.568999          1.541813e+09
# 22  2024-08-03T13:20:00.000Z         0.113026          8.649327e+08
# 23  2024-08-03T13:19:00.000Z         6.151944          2.955868e+08
# 24  2024-08-03T13:19:00.000Z         0.369039          3.507483e+08
# 25  2024-08-03T13:19:00.000Z         0.124791          3.413629e+08
# 26  2024-08-03T13:19:00.000Z        24.011863          3.150509e+08
# 27  2024-08-03T13:19:00.000Z         0.000015          2.654417e+08
# 28  2024-08-03T13:20:00.000Z         5.165352          1.571357e+08
# 29  2024-08-03T13:19:00.000Z       379.056832          3.446901e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -2.2057                    -0.075293
# 1                       11.5241                     0.121795
# 2                        9.6968                    -0.010264
# 3                       -1.9614                     0.046404
# 4                        3.9839                    -0.364348
# 5                        4.8657                    -0.013435
# 6                      -20.8587                    -0.358756
# 7                        1.3264                     0.074834
# 8                       15.1278                    -0.216685
# 9                       -6.0954                    -0.391147
# 10                       3.0810                     0.144364
# 11                      -1.2742                     0.529133
# 12                      -2.1306                     0.151573
# 13                     -13.4498                    -0.129036
# 14                       6.9080                    -0.483774
# 15                      -2.4942                    -0.150866
# 16                      11.5229                     0.078511
# 17                       9.6692                    -0.001646
# 18                      -1.9579                     0.120306
# 19                       3.9789                    -0.325637
# 20                       4.8665                    -0.025038
# 21                     -20.9944                    -0.382293
# 22                       1.2956                     0.026517
# 23                      15.1885                    -0.242615
# 24                      -6.0928                    -0.296951
# 25                       3.0955                     0.151532
# 26                      -1.2690                     0.446288
# 27                      -2.1316                     0.177698
# 28                     -13.7050                    -0.159810
# 29                       6.9048                    -0.404473
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -4.485236                   -10.136972
# 1                      -4.711226                    -9.329283
# 2                      -0.011803                    -0.084912
# 3                      -5.411507                    -8.193595
# 4                      -7.028943                   -18.721650
# 5                      -0.011613                    -0.006087
# 6                      -0.422639                    -5.975250
# 7                      -3.783569                   -17.005514
# 8                      -7.104280                    -8.506340
# 9                      -2.991452                   -12.617123
# 10                     -1.068852                    -9.212675
# 11                     -3.410957                   -17.419084
# 12                     -5.148178                   -15.383235
# 13                     -1.243394                   -12.728987
# 14                     -8.517319                    -1.830159
# 15                     -4.466867                   -10.116189
# 16                     -4.701713                    -9.452504
# 17                      0.010330                    -0.091956
# 18                     -5.421555                    -8.201719
# 19                     -7.121418                   -18.634012
# 20                     -0.003042                    -0.017678
# 21                     -0.449180                    -5.999080
# 22                     -3.842420                   -17.019086
# 23                     -7.163296                    -8.548947
# 24                     -3.063446                   -12.660341
# 25                     -1.033374                    -9.199107
# 26                     -3.581008                   -17.500370
# 27                     -5.234934                   -15.350319
# 28                     -1.271737                   -12.745842
# 29                     -8.812415                    -1.752860
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       8.369492                    -10.563515
# 1                      -3.923906                    -20.395800
# 2                      -0.019209                     -0.044259
# 3                       4.940569                    -16.533134
# 4                      14.514682                     -8.321625
# 5                      -0.024555                     -0.006416
# 6                      28.754047                      8.498839
# 7                       6.038652                    -28.847946
# 8                     -14.496680                    -11.046747
# 9                      -2.994208                    -19.022892
# 10                     -1.084887                      9.557180
# 11                     -4.413042                    -31.247587
# 12                     -0.607974                    -38.377744
# 13                     -8.799700                    -26.311202
# 14                     10.935737                    -18.859794
# 15                      8.375247                    -10.672287
# 16                     -3.982343                    -20.403976
# 17                      0.009791                     -0.039719
# 18                      5.216235                    -16.509401
# 19                     15.014205                     -8.368051
# 20                      0.003385                     -0.004543
# 21                     28.760711                      8.478333
# 22                      6.016255                    -28.886443
# 23                    -14.379912                    -11.055794
# 24                     -2.613700                    -19.043694
# 25                     -0.921583                      9.580914
# 26                     -4.127620                    -31.280281
# 27                     -0.134439                    -38.360514
# 28                     -8.741005                    -26.333945
# 29                     11.520345                    -18.823316
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -3.126889          1.221632e+12
# 1                      -4.291314          3.610862e+11
# 2                      -0.090890          1.144589e+11
# 3                      -7.605615          7.903299e+10
# 4                       3.950259          7.065414e+10
# 5                      -0.010020          3.305752e+10
# 6                       7.858289          3.187119e+10
# 7                     -29.481176          1.643900e+10
# 8                       6.309575          1.549370e+10
# 9                     -19.133740          1.325179e+10
# 10                      3.018633          1.085497e+10
# 11                    -34.810918          9.491852e+09
# 12                    -40.362435          8.666653e+09
# 13                    -26.582593          7.627768e+09
# 14                    -18.056637          7.479821e+09
# 15                     -3.492328          1.220864e+12
# 16                     -4.454420          3.611437e+11
# 17                     -0.090646          1.144622e+11
# 18                     -7.616441          7.907589e+10
# 19                      3.877941          7.067951e+10
# 20                      0.001026          3.305783e+10
# 21                      7.759859          3.186356e+10
# 22                    -29.581705          1.643195e+10
# 23                      6.148798          1.549098e+10
# 24                    -19.121106          1.325466e+10
# 25                      3.050790          1.086005e+10
# 26                    -34.898311          9.485190e+09
# 27                    -40.412546          8.669600e+09
# 28                    -26.686394          7.625931e+09
# 29                    -18.044119          7.483315e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          55.4211                        1.299936e+12
# 1                          16.3853                        3.610862e+11
# 2                           5.1939                        1.169825e+11
# 3                           3.5863                        7.903299e+10
# 4                           3.2061                        8.828209e+10
# 5                           1.5001                        3.305752e+10
# 6                           1.4462                        5.691356e+10
# 7                           0.7460                        1.643900e+10
# 8                           0.7031                        3.144162e+10
# 9                           0.6013                        1.660316e+10
# 10                          0.4926                        1.085497e+10
# 11                          0.4307                        1.719853e+10
# 12                          0.3933                        8.670309e+09
# 13                          0.3461                        7.627768e+09
# 14                          0.3394                        7.956477e+09
# 15                         55.3863                        1.299119e+12
# 16                         16.3879                        3.611437e+11
# 17                          5.1940                        1.169859e+11
# 18                          3.5883                        7.907589e+10
# 19                          3.2073                        8.831378e+10
# 20                          1.5001                        3.305783e+10
# 21                          1.4459                        5.689994e+10
# 22                          0.7456                        1.643195e+10
# 23                          0.7029                        3.143611e+10
# 24                          0.6015                        1.660676e+10
# 25                          0.4928                        1.086005e+10
# 26                          0.4304                        1.718646e+10
# 27                          0.3934                        8.673257e+09
# 28                          0.3460                        7.625931e+09
# 29                          0.3396                        7.960193e+09
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 1             NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 2             NaN  2024-08-03T13:18:00.000Z       1027.0      Ethereum
# 3             NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 4             NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 5             NaN  2024-08-03T13:18:00.000Z       1027.0      Ethereum
# 6             NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 7             NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 8             NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 9             NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 10            NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 11            NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 12            NaN  2024-08-03T13:18:00.000Z       1027.0      Ethereum
# 13            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 14            NaN  2024-08-03T13:18:00.000Z          NaN           NaN
# 15            NaN  2024-08-03T13:20:00.000Z          NaN           NaN
# 16            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 17            NaN  2024-08-03T13:19:00.000Z       1027.0      Ethereum
# 18            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 19            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 20            NaN  2024-08-03T13:19:00.000Z       1027.0      Ethereum
# 21            NaN  2024-08-03T13:20:00.000Z          NaN           NaN
# 22            NaN  2024-08-03T13:20:00.000Z          NaN           NaN
# 23            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 24            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 25            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 26            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
# 27            NaN  2024-08-03T13:19:00.000Z       1027.0      Ethereum
# 28            NaN  2024-08-03T13:20:00.000Z          NaN           NaN
# 29            NaN  2024-08-03T13:19:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
# 15             NaN           NaN                                         NaN
# 16             NaN           NaN                                         NaN
# 17             ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18             NaN           NaN                                         NaN
# 19             NaN           NaN                                         NaN
# 20             ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21             NaN           NaN                                         NaN
# 22             NaN           NaN                                         NaN
# 23             NaN           NaN                                         NaN
# 24             NaN           NaN                                         NaN
# 25             NaN           NaN                                         NaN
# 26             NaN           NaN                                         NaN
# 27             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 28             NaN           NaN                                         NaN
# 29             NaN           NaN                                         NaN
#
#                      timestamp
# 0   2024-08-03 13:20:21.498098
# 1   2024-08-03 13:20:21.498098
# 2   2024-08-03 13:20:21.498098
# 3   2024-08-03 13:20:21.498098
# 4   2024-08-03 13:20:21.498098
# 5   2024-08-03 13:20:21.498098
# 6   2024-08-03 13:20:21.498098
# 7   2024-08-03 13:20:21.498098
# 8   2024-08-03 13:20:21.498098
# 9   2024-08-03 13:20:21.498098
# 10  2024-08-03 13:20:21.498098
# 11  2024-08-03 13:20:21.498098
# 12  2024-08-03 13:20:21.498098
# 13  2024-08-03 13:20:21.498098
# 14  2024-08-03 13:20:21.498098
# 15  2024-08-03 13:21:23.099394
# 16  2024-08-03 13:21:23.099394
# 17  2024-08-03 13:21:23.099394
# 18  2024-08-03 13:21:23.099394
# 19  2024-08-03 13:21:23.099394
# 20  2024-08-03 13:21:23.099394
# 21  2024-08-03 13:21:23.099394
# 22  2024-08-03 13:21:23.099394
# 23  2024-08-03 13:21:23.099394
# 24  2024-08-03 13:21:23.099394
# 25  2024-08-03 13:21:23.099394
# 26  2024-08-03 13:21:23.099394
# 27  2024-08-03 13:21:23.099394
# 28  2024-08-03 13:21:23.099394
# 29  2024-08-03 13:21:23.099394

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11621
# 1    1027      Ethereum    ETH      ethereum              9184
# 2     825   Tether USDt   USDT        tether             93462
# 3    1839           BNB    BNB           bnb              2203
# 4    5426        Solana    SOL        solana               712
# 5    3408          USDC   USDC      usd-coin             21299
# 6      52           XRP    XRP           xrp              1359
# 7      74      Dogecoin   DOGE      dogecoin              1032
# 8   11419       Toncoin    TON       toncoin               487
# 9    2010       Cardano    ADA       cardano              1219
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               759
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               797
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               908
# 0       1       Bitcoin    BTC       bitcoin             11621
# 1    1027      Ethereum    ETH      ethereum              9184
# 2     825   Tether USDt   USDT        tether             93462
# 3    1839           BNB    BNB           bnb              2203
# 4    5426        Solana    SOL        solana               712
# 5    3408          USDC   USDC      usd-coin             21299
# 6      52           XRP    XRP           xrp              1359
# 7      74      Dogecoin   DOGE      dogecoin              1032
# 8   11419       Toncoin    TON       toncoin               487
# 9    2010       Cardano    ADA       cardano              1219
# 10   1958          TRON    TRX          tron              1006
# 11   5805     Avalanche   AVAX     avalanche               759
# 12   5994     Shiba Inu   SHIB     shiba-inu               854
# 13   6636      Polkadot    DOT  polkadot-new               797
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               908
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2021-08-26T13:40:22.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2021-08-26T13:40:22.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 9   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 10  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 9   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 10  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19735059.00000        19735059.00000            False       NaN
# 1        120255176.29602       120255176.29602             True       NaN
# 2     114542666302.87727    117068083203.71024             True       NaN
# 3        145937202.56487       145937202.56487            False       NaN
# 4        465386728.45385       581499547.53824             True       NaN
# 5      33065101495.23913     33065101495.23913            False       NaN
# 6      55999283950.00000     99987385748.00000            False       NaN
# 7     145383216383.70520    145383216383.70520             True       NaN
# 8       2518067442.25076      5109951796.88987             True       NaN
# 9      35916674706.16400     37102998493.68500            False       NaN
# 10     87024944908.48790     87024951669.70393             True       NaN
# 11       395030030.61458       444376400.61458            False       NaN
# 12 589270520002237.75000 589519083993420.62500            False       NaN
# 13      1476363743.59898      1476363743.59898             True       NaN
# 14        19741971.87500        19741971.87500            False       NaN
# 0         19735059.00000        19735059.00000            False       NaN
# 1        120255176.29602       120255176.29602             True       NaN
# 2     114542666302.87727    117068083203.71024             True       NaN
# 3        145937202.56487       145937202.56487            False       NaN
# 4        465386728.45385       581499547.53824             True       NaN
# 5      33065101495.23913     33065101495.23913            False       NaN
# 6      55999283950.00000     99987385748.00000            False       NaN
# 7     145383216383.70520    145383216383.70520             True       NaN
# 8       2518067442.25076      5109951796.88987             True       NaN
# 9      35916674706.16400     37102998493.68500            False       NaN
# 10     87024944908.48790     87024951669.70393             True       NaN
# 11       395030030.61458       444376400.61458            False       NaN
# 12 589270520002237.75000 589519083993420.62500            False       NaN
# 13      1476363743.59898      1476363743.59898             True       NaN
# 14        19741971.87500        19741971.87500            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                  3414166606.00000         20797431390.10850
# 9         10                               NaN                       NaN
# 10        11                 71659659264.00000          8958667812.04023
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                  1476363743.90392          7534532893.68831
# 14        15                               NaN                       NaN
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                  3414166606.00000         20797431390.10850
# 9         10                               NaN                       NaN
# 10        11                 71659659264.00000          8958667812.04023
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                  1476363743.90392          7534532893.68831
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2024-08-03T15:43:00.000Z      61320.86418     33258996160.52995
# 1       None  2024-08-03T15:42:00.000Z       2969.93585     17189932444.82347
# 2       None  2024-08-03T15:42:00.000Z          0.99940     60581381625.13857
# 3       None  2024-08-03T15:42:00.000Z        535.24781      1864137317.42236
# 4       None  2024-08-03T15:42:00.000Z        148.69145      3570577735.40798
# 5       None  2024-08-03T15:42:00.000Z          1.00000      6295233485.86936
# 6       None  2024-08-03T15:43:00.000Z          0.56061      1287779195.60584
# 7       None  2024-08-03T15:43:00.000Z          0.11166       734150732.06924
# 8       None  2024-08-03T15:42:00.000Z          6.09151       245595180.17943
# 9       None  2024-08-03T15:42:00.000Z          0.36496       280937792.22975
# 10      None  2024-08-03T15:42:00.000Z          0.12502       310271466.40966
# 11      None  2024-08-03T15:42:00.000Z         23.59956       254448521.44657
# 12      None  2024-08-03T15:42:00.000Z          0.00001       220839061.68736
# 13      None  2024-08-03T15:43:00.000Z          5.10344       130656769.98311
# 14      None  2024-08-03T15:42:00.000Z        371.64688       311235591.65103
# 0       None  2024-08-03T15:43:00.000Z      61320.86418     33258996160.52995
# 1       None  2024-08-03T15:42:00.000Z       2969.93585     17189932444.82347
# 2       None  2024-08-03T15:42:00.000Z          0.99940     60581381625.13857
# 3       None  2024-08-03T15:42:00.000Z        535.24781      1864137317.42236
# 4       None  2024-08-03T15:42:00.000Z        148.69145      3570577735.40798
# 5       None  2024-08-03T15:42:00.000Z          1.00000      6295233485.86936
# 6       None  2024-08-03T15:43:00.000Z          0.56061      1287779195.60584
# 7       None  2024-08-03T15:43:00.000Z          0.11166       734150732.06924
# 8       None  2024-08-03T15:42:00.000Z          6.09151       245595180.17943
# 9       None  2024-08-03T15:42:00.000Z          0.36496       280937792.22975
# 10      None  2024-08-03T15:42:00.000Z          0.12502       310271466.40966
# 11      None  2024-08-03T15:42:00.000Z         23.59956       254448521.44657
# 12      None  2024-08-03T15:42:00.000Z          0.00001       220839061.68736
# 13      None  2024-08-03T15:43:00.000Z          5.10344       130656769.98311
# 14      None  2024-08-03T15:42:00.000Z        371.64688       311235591.65103
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -25.27050                     -1.19094
# 1                     -18.19960                     -1.24056
# 2                     -13.95630                     -0.00096
# 3                     -10.81720                     -1.58422
# 4                     -21.74860                     -2.44840
# 5                     -22.90430                      0.00099
# 6                     -36.39260                     -1.65675
# 7                     -19.79560                     -1.90432
# 8                     -13.53890                     -0.71465
# 9                     -32.07170                     -1.32825
# 10                    -10.54540                     -0.18934
# 11                    -26.92540                     -1.77208
# 12                    -24.62350                     -2.16725
# 13                    -30.05170                     -1.55813
# 14                     -8.65450                     -2.10962
# 0                     -25.27050                     -1.19094
# 1                     -18.19960                     -1.24056
# 2                     -13.95630                     -0.00096
# 3                     -10.81720                     -1.58422
# 4                     -21.74860                     -2.44840
# 5                     -22.90430                      0.00099
# 6                     -36.39260                     -1.65675
# 7                     -19.79560                     -1.90432
# 8                     -13.53890                     -0.71465
# 9                     -32.07170                     -1.32825
# 10                    -10.54540                     -0.18934
# 11                    -26.92540                     -1.77208
# 12                    -24.62350                     -2.16725
# 13                    -30.05170                     -1.55813
# 14                     -8.65450                     -2.10962
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -2.88788                    -10.85552
# 1                       -1.89275                     -9.63558
# 2                        0.02554                     -0.08627
# 3                       -3.74101                     -8.36151
# 4                       -4.68724                    -18.49797
# 5                       -0.00498                     -0.02313
# 6                        0.35850                     -6.32603
# 7                       -1.21807                    -17.00546
# 8                       -5.02206                     -8.61884
# 9                       -0.42782                    -13.53667
# 10                       1.43620                     -9.00437
# 11                      -1.86813                    -18.26436
# 12                      -3.53185                    -15.58456
# 13                      -0.14729                    -12.36592
# 14                      -6.65709                     -5.64308
# 0                       -2.88788                    -10.85552
# 1                       -1.89275                     -9.63558
# 2                        0.02554                     -0.08627
# 3                       -3.74101                     -8.36151
# 4                       -4.68724                    -18.49797
# 5                       -0.00498                     -0.02313
# 6                        0.35850                     -6.32603
# 7                       -1.21807                    -17.00546
# 8                       -5.02206                     -8.61884
# 9                       -0.42782                    -13.53667
# 10                       1.43620                     -9.00437
# 11                      -1.86813                    -18.26436
# 12                      -3.53185                    -15.58456
# 13                      -0.14729                    -12.36592
# 14                      -6.65709                     -5.64308
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                        6.53982                     -12.61231
# 1                       -4.87878                     -21.88499
# 2                        0.01274                      -0.05466
# 3                        2.81702                     -19.34840
# 4                       10.90693                     -10.75083
# 5                       -0.00176                      -0.00877
# 6                       26.58489                       6.18547
# 7                        2.14527                     -30.22027
# 8                      -15.16841                     -12.83632
# 9                       -4.56769                     -20.56342
# 10                      -0.78774                       9.49932
# 11                      -6.92896                     -33.81035
# 12                      -4.01664                     -40.15674
# 13                     -11.80153                     -28.83551
# 14                       8.89895                     -21.62877
# 0                        6.53982                     -12.61231
# 1                       -4.87878                     -21.88499
# 2                        0.01274                      -0.05466
# 3                        2.81702                     -19.34840
# 4                       10.90693                     -10.75083
# 5                       -0.00176                      -0.00877
# 6                       26.58489                       6.18547
# 7                        2.14527                     -30.22027
# 8                      -15.16841                     -12.83632
# 9                       -4.56769                     -20.56342
# 10                      -0.78774                       9.49932
# 11                      -6.92896                     -33.81035
# 12                      -4.01664                     -40.15674
# 13                     -11.80153                     -28.83551
# 14                       8.89895                     -21.62877
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       -4.70405   1210170872424.88208
# 1                       -5.88167    357150159582.18860
# 2                       -0.07019    114473396969.67476
# 3                       -9.52083     78112567466.05829
# 4                        0.96734     69199025641.39992
# 5                       -0.00368     33065221954.36136
# 6                        5.55022     31393694162.59607
# 7                      -30.89969     16232836435.26721
# 8                        2.14648     15338834014.08799
# 9                      -21.05514     13108109941.45180
# 10                       3.01385     10879588052.79877
# 11                     -36.61468      9322534932.62775
# 12                     -41.84209      8532132738.75350
# 13                     -29.32948      7534532892.13206
# 14                     -20.53675      7337042180.26427
# 0                       -4.70405   1210170872424.88208
# 1                       -5.88167    357150159582.18860
# 2                       -0.07019    114473396969.67476
# 3                       -9.52083     78112567466.05829
# 4                        0.96734     69199025641.39992
# 5                       -0.00368     33065221954.36136
# 6                        5.55022     31393694162.59607
# 7                      -30.89969     16232836435.26721
# 8                        2.14648     15338834014.08799
# 9                      -21.05514     13108109941.45180
# 10                       3.01385     10879588052.79877
# 11                     -36.61468      9322534932.62775
# 12                     -41.84209      8532132738.75350
# 13                     -29.32948      7534532892.13206
# 14                     -20.53675      7337042180.26427
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         55.45510                 1287738147675.29004
# 1                         16.36950                  357150159582.19000
# 2                          5.24670                  116997286632.23000
# 3                          3.58020                   78112567466.06000
# 4                          3.17160                   86464008619.77000
# 5                          1.51550                   33065221954.36000
# 6                          1.43890                   56060884976.01000
# 7                          0.74400                   16232836435.27000
# 8                          0.70300                   31127324517.74000
# 9                          0.60080                   16423150310.85000
# 10                         0.49870                   10879588898.06000
# 11                         0.42730                   16891354881.25000
# 12                         0.39110                    8535731732.59000
# 13                         0.34530                    7534532892.13000
# 14                         0.33630                    7804584403.28000
# 0                         55.45510                 1287738147675.29004
# 1                         16.36950                  357150159582.19000
# 2                          5.24670                  116997286632.23000
# 3                          3.58020                   78112567466.06000
# 4                          3.17160                   86464008619.77000
# 5                          1.51550                   33065221954.36000
# 6                          1.43890                   56060884976.01000
# 7                          0.74400                   16232836435.27000
# 8                          0.70300                   31127324517.74000
# 9                          0.60080                   16423150310.85000
# 10                         0.49870                   10879588898.06000
# 11                         0.42730                   16891354881.25000
# 12                         0.39110                    8535731732.59000
# 13                         0.34530                    7534532892.13000
# 14                         0.33630                    7804584403.28000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 1           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 2           None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 3           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 4           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 5           None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 6           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 7           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 8           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 9           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 10          None  2024-08-03T15:42:00.000Z          NaN           NaN
# 11          None  2024-08-03T15:42:00.000Z          NaN           NaN
# 12          None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 13          None  2024-08-03T15:43:00.000Z          NaN           NaN
# 14          None  2024-08-03T15:42:00.000Z          NaN           NaN
# 0           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 1           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 2           None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 3           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 4           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 5           None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 6           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 7           None  2024-08-03T15:43:00.000Z          NaN           NaN
# 8           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 9           None  2024-08-03T15:42:00.000Z          NaN           NaN
# 10          None  2024-08-03T15:42:00.000Z          NaN           NaN
# 11          None  2024-08-03T15:42:00.000Z          NaN           NaN
# 12          None  2024-08-03T15:42:00.000Z   1027.00000      Ethereum
# 13          None  2024-08-03T15:43:00.000Z          NaN           NaN
# 14          None  2024-08-03T15:42:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp                  Timestamp
# 0  2024-08-03 15:44:29.894944                        NaT
# 1  2024-08-03 15:44:29.894944                        NaT
# 2  2024-08-03 15:44:29.894944                        NaT
# 3  2024-08-03 15:44:29.894944                        NaT
# 4  2024-08-03 15:44:29.894944                        NaT
# 5  2024-08-03 15:44:29.894944                        NaT
# 6  2024-08-03 15:44:29.894944                        NaT
# 7  2024-08-03 15:44:29.894944                        NaT
# 8  2024-08-03 15:44:29.894944                        NaT
# 9  2024-08-03 15:44:29.894944                        NaT
# 10 2024-08-03 15:44:29.894944                        NaT
# 11 2024-08-03 15:44:29.894944                        NaT
# 12 2024-08-03 15:44:29.894944                        NaT
# 13 2024-08-03 15:44:29.894944                        NaT
# 14 2024-08-03 15:44:29.894944                        NaT
# 0                         NaT 2024-08-03 15:44:29.906009
# 1                         NaT 2024-08-03 15:44:29.906009
# 2                         NaT 2024-08-03 15:44:29.906009
# 3                         NaT 2024-08-03 15:44:29.906009
# 4                         NaT 2024-08-03 15:44:29.906009
# 5                         NaT 2024-08-03 15:44:29.906009
# 6                         NaT 2024-08-03 15:44:29.906009
# 7                         NaT 2024-08-03 15:44:29.906009
# 8                         NaT 2024-08-03 15:44:29.906009
# 9                         NaT 2024-08-03 15:44:29.906009
# 10                        NaT 2024-08-03 15:44:29.906009
# 11                        NaT 2024-08-03 15:44:29.906009
# 12                        NaT 2024-08-03 15:44:29.906009
# 13                        NaT 2024-08-03 15:44:29.906009
# 14                        NaT 2024-08-03 15:44:29.906009

# %%
df3 = df.groupby('name', sort = False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -1.19094                      -2.88788
# Ethereum                         -1.24056                      -1.89275
# Tether USDt                      -0.00096                       0.02554
# BNB                              -1.58422                      -3.74101
# Solana                           -2.44840                      -4.68724
# USDC                              0.00099                      -0.00498
# XRP                              -1.65675                       0.35850
# Dogecoin                         -1.90432                      -1.21807
# Toncoin                          -0.71465                      -5.02206
# Cardano                          -1.32825                      -0.42782
# TRON                             -0.18934                       1.43620
# Avalanche                        -1.77208                      -1.86813
# Shiba Inu                        -2.16725                      -3.53185
# Polkadot                         -1.55813                      -0.14729
# Bitcoin Cash                     -2.10962                      -6.65709
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -10.85552                       6.53982
# Ethereum                         -9.63558                      -4.87878
# Tether USDt                      -0.08627                       0.01274
# BNB                              -8.36151                       2.81702
# Solana                          -18.49797                      10.90693
# USDC                             -0.02313                      -0.00176
# XRP                              -6.32603                      26.58489
# Dogecoin                        -17.00546                       2.14527
# Toncoin                          -8.61884                     -15.16841
# Cardano                         -13.53667                      -4.56769
# TRON                             -9.00437                      -0.78774
# Avalanche                       -18.26436                      -6.92896
# Shiba Inu                       -15.58456                      -4.01664
# Polkadot                        -12.36592                     -11.80153
# Bitcoin Cash                     -5.64308                       8.89895
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -12.61231                      -4.70405
# Ethereum                         -21.88499                      -5.88167
# Tether USDt                       -0.05466                      -0.07019
# BNB                              -19.34840                      -9.52083
# Solana                           -10.75083                       0.96734
# USDC                              -0.00877                      -0.00368
# XRP                                6.18547                       5.55022
# Dogecoin                         -30.22027                     -30.89969
# Toncoin                          -12.83632                       2.14648
# Cardano                          -20.56342                     -21.05514
# TRON                               9.49932                       3.01385
# Avalanche                        -33.81035                     -36.61468
# Shiba Inu                        -40.15674                     -41.84209
# Polkadot                         -28.83551                     -29.32948
# Bitcoin Cash                     -21.62877                     -20.53675

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.23919
#               quote.USD.percent_change_24h    -1.60619
#               quote.USD.percent_change_7d    -10.09599
#               quote.USD.percent_change_30d     7.62232
#               quote.USD.percent_change_60d   -11.51947
#               quote.USD.percent_change_90d    -3.56586
# Ethereum      quote.USD.percent_change_1h     -0.31745
#               quote.USD.percent_change_24h    -0.05870
#               quote.USD.percent_change_7d     -8.98447
#               quote.USD.percent_change_30d    -3.96185
#               quote.USD.percent_change_60d   -20.96424
#               quote.USD.percent_change_90d    -4.99493
# Tether USDt   quote.USD.percent_change_1h      0.00411
#               quote.USD.percent_change_24h     0.04678
#               quote.USD.percent_change_7d     -0.07110
#               quote.USD.percent_change_30d    -0.02748
#               quote.USD.percent_change_60d    -0.05931
#               quote.USD.percent_change_90d    -0.07831
# BNB           quote.USD.percent_change_1h     -0.13946
#               quote.USD.percent_change_24h    -1.51053
#               quote.USD.percent_change_7d     -7.53501
#               quote.USD.percent_change_30d     3.95554
#               quote.USD.percent_change_60d   -17.90638
#               quote.USD.percent_change_90d    -8.38227
# Solana        quote.USD.percent_change_1h     -0.43112
#               quote.USD.percent_change_24h    -2.12157
#               quote.USD.percent_change_7d    -17.53748
#               quote.USD.percent_change_30d    12.41455
#               quote.USD.percent_change_60d    -8.92555
#               quote.USD.percent_change_90d     2.55217
# USDC          quote.USD.percent_change_1h      0.00783
#               quote.USD.percent_change_24h     0.01652
#               quote.USD.percent_change_7d      0.00179
#               quote.USD.percent_change_30d    -0.04594
#               quote.USD.percent_change_60d    -0.03259
#               quote.USD.percent_change_90d     0.00143
# XRP           quote.USD.percent_change_1h     -0.67692
#               quote.USD.percent_change_24h     2.69544
#               quote.USD.percent_change_7d     -5.24464
#               quote.USD.percent_change_30d    27.37766
#               quote.USD.percent_change_60d     7.34141
#               quote.USD.percent_change_90d     6.96890
# Dogecoin      quote.USD.percent_change_1h     -0.29626
#               quote.USD.percent_change_24h     1.81550
#               quote.USD.percent_change_7d    -16.00509
#               quote.USD.percent_change_30d     4.22205
#               quote.USD.percent_change_60d   -29.02507
#               quote.USD.percent_change_90d   -29.63259
# Toncoin       quote.USD.percent_change_1h     -0.14831
#               quote.USD.percent_change_24h    -4.24505
#               quote.USD.percent_change_7d     -8.16359
#               quote.USD.percent_change_30d   -14.72949
#               quote.USD.percent_change_60d   -12.18985
#               quote.USD.percent_change_90d     4.05118
# Cardano       quote.USD.percent_change_1h     -0.39495
#               quote.USD.percent_change_24h     2.02375
#               quote.USD.percent_change_7d    -12.90318
#               quote.USD.percent_change_30d    -3.70911
#               quote.USD.percent_change_60d   -19.65179
#               quote.USD.percent_change_90d   -20.31735
# TRON          quote.USD.percent_change_1h     -0.07678
#               quote.USD.percent_change_24h     0.61149
#               quote.USD.percent_change_7d     -8.87992
#               quote.USD.percent_change_30d    -0.72536
#               quote.USD.percent_change_60d     9.60042
#               quote.USD.percent_change_90d     3.11271
# Avalanche     quote.USD.percent_change_1h     -0.80096
#               quote.USD.percent_change_24h     1.16910
#               quote.USD.percent_change_7d    -17.90506
#               quote.USD.percent_change_30d    -5.89832
#               quote.USD.percent_change_60d   -32.82681
#               quote.USD.percent_change_90d   -36.06750
# Shiba Inu     quote.USD.percent_change_1h     -0.23909
#               quote.USD.percent_change_24h    -0.32722
#               quote.USD.percent_change_7d    -14.41825
#               quote.USD.percent_change_30d    -1.71600
#               quote.USD.percent_change_60d   -38.90892
#               quote.USD.percent_change_90d   -40.73730
# Polkadot      quote.USD.percent_change_1h     -0.50993
#               quote.USD.percent_change_24h     2.40823
#               quote.USD.percent_change_7d    -11.78612
#               quote.USD.percent_change_30d   -10.33906
#               quote.USD.percent_change_60d   -27.84348
#               quote.USD.percent_change_90d   -28.29764
# Bitcoin Cash  quote.USD.percent_change_1h     -0.47528
#               quote.USD.percent_change_24h    -3.39906
#               quote.USD.percent_change_7d     -4.05295
#               quote.USD.percent_change_30d    10.30627
#               quote.USD.percent_change_60d   -19.85775
#               quote.USD.percent_change_90d   -19.24750
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name = 'values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.23919
#              quote.USD.percent_change_24h  -1.60619
#              quote.USD.percent_change_7d  -10.09599
#              quote.USD.percent_change_30d   7.62232
#              quote.USD.percent_change_60d -11.51947
#              quote.USD.percent_change_90d  -3.56586
# Ethereum     quote.USD.percent_change_1h   -0.31745
#              quote.USD.percent_change_24h  -0.05870
#              quote.USD.percent_change_7d   -8.98447
#              quote.USD.percent_change_30d  -3.96185
#              quote.USD.percent_change_60d -20.96424
#              quote.USD.percent_change_90d  -4.99493
# Tether USDt  quote.USD.percent_change_1h    0.00411
#              quote.USD.percent_change_24h   0.04678
#              quote.USD.percent_change_7d   -0.07110
#              quote.USD.percent_change_30d  -0.02748
#              quote.USD.percent_change_60d  -0.05931
#              quote.USD.percent_change_90d  -0.07831
# BNB          quote.USD.percent_change_1h   -0.13946
#              quote.USD.percent_change_24h  -1.51053
#              quote.USD.percent_change_7d   -7.53501
#              quote.USD.percent_change_30d   3.95554
#              quote.USD.percent_change_60d -17.90638
#              quote.USD.percent_change_90d  -8.38227
# Solana       quote.USD.percent_change_1h   -0.43112
#              quote.USD.percent_change_24h  -2.12157
#              quote.USD.percent_change_7d  -17.53748
#              quote.USD.percent_change_30d  12.41455
#              quote.USD.percent_change_60d  -8.92555
#              quote.USD.percent_change_90d   2.55217
# USDC         quote.USD.percent_change_1h    0.00783
#              quote.USD.percent_change_24h   0.01652
#              quote.USD.percent_change_7d    0.00179
#              quote.USD.percent_change_30d  -0.04594
#              quote.USD.percent_change_60d  -0.03259
#              quote.USD.percent_change_90d   0.00143
# XRP          quote.USD.percent_change_1h   -0.67692
#              quote.USD.percent_change_24h   2.69544
#              quote.USD.percent_change_7d   -5.24464
#              quote.USD.percent_change_30d  27.37766
#              quote.USD.percent_change_60d   7.34141
#              quote.USD.percent_change_90d   6.96890
# Dogecoin     quote.USD.percent_change_1h   -0.29626
#              quote.USD.percent_change_24h   1.81550
#              quote.USD.percent_change_7d  -16.00509
#              quote.USD.percent_change_30d   4.22205
#              quote.USD.percent_change_60d -29.02507
#              quote.USD.percent_change_90d -29.63259
# Toncoin      quote.USD.percent_change_1h   -0.14831
#              quote.USD.percent_change_24h  -4.24505
#              quote.USD.percent_change_7d   -8.16359
#              quote.USD.percent_change_30d -14.72949
#              quote.USD.percent_change_60d -12.18985
#              quote.USD.percent_change_90d   4.05118
# Cardano      quote.USD.percent_change_1h   -0.39495
#              quote.USD.percent_change_24h   2.02375
#              quote.USD.percent_change_7d  -12.90318
#              quote.USD.percent_change_30d  -3.70911
#              quote.USD.percent_change_60d -19.65179
#              quote.USD.percent_change_90d -20.31735
# TRON         quote.USD.percent_change_1h   -0.07678
#              quote.USD.percent_change_24h   0.61149
#              quote.USD.percent_change_7d   -8.87992
#              quote.USD.percent_change_30d  -0.72536
#              quote.USD.percent_change_60d   9.60042
#              quote.USD.percent_change_90d   3.11271
# Avalanche    quote.USD.percent_change_1h   -0.80096
#              quote.USD.percent_change_24h   1.16910
#              quote.USD.percent_change_7d  -17.90506
#              quote.USD.percent_change_30d  -5.89832
#              quote.USD.percent_change_60d -32.82681
#              quote.USD.percent_change_90d -36.06750
# Shiba Inu    quote.USD.percent_change_1h   -0.23909
#              quote.USD.percent_change_24h  -0.32722
#              quote.USD.percent_change_7d  -14.41825
#              quote.USD.percent_change_30d  -1.71600
#              quote.USD.percent_change_60d -38.90892
#              quote.USD.percent_change_90d -40.73730
# Polkadot     quote.USD.percent_change_1h   -0.50993
#              quote.USD.percent_change_24h   2.40823
#              quote.USD.percent_change_7d  -11.78612
#              quote.USD.percent_change_30d -10.33906
#              quote.USD.percent_change_60d -27.84348
#              quote.USD.percent_change_90d -28.29764
# Bitcoin Cash quote.USD.percent_change_1h   -0.47528
#              quote.USD.percent_change_24h  -3.39906
#              quote.USD.percent_change_7d   -4.05295
#              quote.USD.percent_change_30d  10.30627
#              quote.USD.percent_change_60d -19.85775
#              quote.USD.percent_change_90d -19.24750

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#             name                       level_1    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.23919
# 1        Bitcoin  quote.USD.percent_change_24h  -1.60619
# 2        Bitcoin   quote.USD.percent_change_7d -10.09599
# 3        Bitcoin  quote.USD.percent_change_30d   7.62232
# 4        Bitcoin  quote.USD.percent_change_60d -11.51947
# 5        Bitcoin  quote.USD.percent_change_90d  -3.56586
# 6       Ethereum   quote.USD.percent_change_1h  -0.31745
# 7       Ethereum  quote.USD.percent_change_24h  -0.05870
# 8       Ethereum   quote.USD.percent_change_7d  -8.98447
# 9       Ethereum  quote.USD.percent_change_30d  -3.96185
# 10      Ethereum  quote.USD.percent_change_60d -20.96424
# 11      Ethereum  quote.USD.percent_change_90d  -4.99493
# 12   Tether USDt   quote.USD.percent_change_1h   0.00411
# 13   Tether USDt  quote.USD.percent_change_24h   0.04678
# 14   Tether USDt   quote.USD.percent_change_7d  -0.07110
# 15   Tether USDt  quote.USD.percent_change_30d  -0.02748
# 16   Tether USDt  quote.USD.percent_change_60d  -0.05931
# 17   Tether USDt  quote.USD.percent_change_90d  -0.07831
# 18           BNB   quote.USD.percent_change_1h  -0.13946
# 19           BNB  quote.USD.percent_change_24h  -1.51053
# 20           BNB   quote.USD.percent_change_7d  -7.53501
# 21           BNB  quote.USD.percent_change_30d   3.95554
# 22           BNB  quote.USD.percent_change_60d -17.90638
# 23           BNB  quote.USD.percent_change_90d  -8.38227
# 24        Solana   quote.USD.percent_change_1h  -0.43112
# 25        Solana  quote.USD.percent_change_24h  -2.12157
# 26        Solana   quote.USD.percent_change_7d -17.53748
# 27        Solana  quote.USD.percent_change_30d  12.41455
# 28        Solana  quote.USD.percent_change_60d  -8.92555
# 29        Solana  quote.USD.percent_change_90d   2.55217
# 30          USDC   quote.USD.percent_change_1h   0.00783
# 31          USDC  quote.USD.percent_change_24h   0.01652
# 32          USDC   quote.USD.percent_change_7d   0.00179
# 33          USDC  quote.USD.percent_change_30d  -0.04594
# 34          USDC  quote.USD.percent_change_60d  -0.03259
# 35          USDC  quote.USD.percent_change_90d   0.00143
# 36           XRP   quote.USD.percent_change_1h  -0.67692
# 37           XRP  quote.USD.percent_change_24h   2.69544
# 38           XRP   quote.USD.percent_change_7d  -5.24464
# 39           XRP  quote.USD.percent_change_30d  27.37766
# 40           XRP  quote.USD.percent_change_60d   7.34141
# 41           XRP  quote.USD.percent_change_90d   6.96890
# 42      Dogecoin   quote.USD.percent_change_1h  -0.29626
# 43      Dogecoin  quote.USD.percent_change_24h   1.81550
# 44      Dogecoin   quote.USD.percent_change_7d -16.00509
# 45      Dogecoin  quote.USD.percent_change_30d   4.22205
# 46      Dogecoin  quote.USD.percent_change_60d -29.02507
# 47      Dogecoin  quote.USD.percent_change_90d -29.63259
# 48       Toncoin   quote.USD.percent_change_1h  -0.14831
# 49       Toncoin  quote.USD.percent_change_24h  -4.24505
# 50       Toncoin   quote.USD.percent_change_7d  -8.16359
# 51       Toncoin  quote.USD.percent_change_30d -14.72949
# 52       Toncoin  quote.USD.percent_change_60d -12.18985
# 53       Toncoin  quote.USD.percent_change_90d   4.05118
# 54       Cardano   quote.USD.percent_change_1h  -0.39495
# 55       Cardano  quote.USD.percent_change_24h   2.02375
# 56       Cardano   quote.USD.percent_change_7d -12.90318
# 57       Cardano  quote.USD.percent_change_30d  -3.70911
# 58       Cardano  quote.USD.percent_change_60d -19.65179
# 59       Cardano  quote.USD.percent_change_90d -20.31735
# 60          TRON   quote.USD.percent_change_1h  -0.07678
# 61          TRON  quote.USD.percent_change_24h   0.61149
# 62          TRON   quote.USD.percent_change_7d  -8.87992
# 63          TRON  quote.USD.percent_change_30d  -0.72536
# 64          TRON  quote.USD.percent_change_60d   9.60042
# 65          TRON  quote.USD.percent_change_90d   3.11271
# 66     Avalanche   quote.USD.percent_change_1h  -0.80096
# 67     Avalanche  quote.USD.percent_change_24h   1.16910
# 68     Avalanche   quote.USD.percent_change_7d -17.90506
# 69     Avalanche  quote.USD.percent_change_30d  -5.89832
# 70     Avalanche  quote.USD.percent_change_60d -32.82681
# 71     Avalanche  quote.USD.percent_change_90d -36.06750
# 72     Shiba Inu   quote.USD.percent_change_1h  -0.23909
# 73     Shiba Inu  quote.USD.percent_change_24h  -0.32722
# 74     Shiba Inu   quote.USD.percent_change_7d -14.41825
# 75     Shiba Inu  quote.USD.percent_change_30d  -1.71600
# 76     Shiba Inu  quote.USD.percent_change_60d -38.90892
# 77     Shiba Inu  quote.USD.percent_change_90d -40.73730
# 78      Polkadot   quote.USD.percent_change_1h  -0.50993
# 79      Polkadot  quote.USD.percent_change_24h   2.40823
# 80      Polkadot   quote.USD.percent_change_7d -11.78612
# 81      Polkadot  quote.USD.percent_change_30d -10.33906
# 82      Polkadot  quote.USD.percent_change_60d -27.84348
# 83      Polkadot  quote.USD.percent_change_90d -28.29764
# 84  Bitcoin Cash   quote.USD.percent_change_1h  -0.47528
# 85  Bitcoin Cash  quote.USD.percent_change_24h  -3.39906
# 86  Bitcoin Cash   quote.USD.percent_change_7d  -4.05295
# 87  Bitcoin Cash  quote.USD.percent_change_30d  10.30627
# 88  Bitcoin Cash  quote.USD.percent_change_60d -19.85775
# 89  Bitcoin Cash  quote.USD.percent_change_90d -19.24750

# %%
df7 = df6.rename(columns = {'level_1' : 'percent_change'})
df7
# Out:
#             name                percent_change    values
# 0        Bitcoin   quote.USD.percent_change_1h  -0.23919
# 1        Bitcoin  quote.USD.percent_change_24h  -1.60619
# 2        Bitcoin   quote.USD.percent_change_7d -10.09599
# 3        Bitcoin  quote.USD.percent_change_30d   7.62232
# 4        Bitcoin  quote.USD.percent_change_60d -11.51947
# 5        Bitcoin  quote.USD.percent_change_90d  -3.56586
# 6       Ethereum   quote.USD.percent_change_1h  -0.31745
# 7       Ethereum  quote.USD.percent_change_24h  -0.05870
# 8       Ethereum   quote.USD.percent_change_7d  -8.98447
# 9       Ethereum  quote.USD.percent_change_30d  -3.96185
# 10      Ethereum  quote.USD.percent_change_60d -20.96424
# 11      Ethereum  quote.USD.percent_change_90d  -4.99493
# 12   Tether USDt   quote.USD.percent_change_1h   0.00411
# 13   Tether USDt  quote.USD.percent_change_24h   0.04678
# 14   Tether USDt   quote.USD.percent_change_7d  -0.07110
# 15   Tether USDt  quote.USD.percent_change_30d  -0.02748
# 16   Tether USDt  quote.USD.percent_change_60d  -0.05931
# 17   Tether USDt  quote.USD.percent_change_90d  -0.07831
# 18           BNB   quote.USD.percent_change_1h  -0.13946
# 19           BNB  quote.USD.percent_change_24h  -1.51053
# 20           BNB   quote.USD.percent_change_7d  -7.53501
# 21           BNB  quote.USD.percent_change_30d   3.95554
# 22           BNB  quote.USD.percent_change_60d -17.90638
# 23           BNB  quote.USD.percent_change_90d  -8.38227
# 24        Solana   quote.USD.percent_change_1h  -0.43112
# 25        Solana  quote.USD.percent_change_24h  -2.12157
# 26        Solana   quote.USD.percent_change_7d -17.53748
# 27        Solana  quote.USD.percent_change_30d  12.41455
# 28        Solana  quote.USD.percent_change_60d  -8.92555
# 29        Solana  quote.USD.percent_change_90d   2.55217
# 30          USDC   quote.USD.percent_change_1h   0.00783
# 31          USDC  quote.USD.percent_change_24h   0.01652
# 32          USDC   quote.USD.percent_change_7d   0.00179
# 33          USDC  quote.USD.percent_change_30d  -0.04594
# 34          USDC  quote.USD.percent_change_60d  -0.03259
# 35          USDC  quote.USD.percent_change_90d   0.00143
# 36           XRP   quote.USD.percent_change_1h  -0.67692
# 37           XRP  quote.USD.percent_change_24h   2.69544
# 38           XRP   quote.USD.percent_change_7d  -5.24464
# 39           XRP  quote.USD.percent_change_30d  27.37766
# 40           XRP  quote.USD.percent_change_60d   7.34141
# 41           XRP  quote.USD.percent_change_90d   6.96890
# 42      Dogecoin   quote.USD.percent_change_1h  -0.29626
# 43      Dogecoin  quote.USD.percent_change_24h   1.81550
# 44      Dogecoin   quote.USD.percent_change_7d -16.00509
# 45      Dogecoin  quote.USD.percent_change_30d   4.22205
# 46      Dogecoin  quote.USD.percent_change_60d -29.02507
# 47      Dogecoin  quote.USD.percent_change_90d -29.63259
# 48       Toncoin   quote.USD.percent_change_1h  -0.14831
# 49       Toncoin  quote.USD.percent_change_24h  -4.24505
# 50       Toncoin   quote.USD.percent_change_7d  -8.16359
# 51       Toncoin  quote.USD.percent_change_30d -14.72949
# 52       Toncoin  quote.USD.percent_change_60d -12.18985
# 53       Toncoin  quote.USD.percent_change_90d   4.05118
# 54       Cardano   quote.USD.percent_change_1h  -0.39495
# 55       Cardano  quote.USD.percent_change_24h   2.02375
# 56       Cardano   quote.USD.percent_change_7d -12.90318
# 57       Cardano  quote.USD.percent_change_30d  -3.70911
# 58       Cardano  quote.USD.percent_change_60d -19.65179
# 59       Cardano  quote.USD.percent_change_90d -20.31735
# 60          TRON   quote.USD.percent_change_1h  -0.07678
# 61          TRON  quote.USD.percent_change_24h   0.61149
# 62          TRON   quote.USD.percent_change_7d  -8.87992
# 63          TRON  quote.USD.percent_change_30d  -0.72536
# 64          TRON  quote.USD.percent_change_60d   9.60042
# 65          TRON  quote.USD.percent_change_90d   3.11271
# 66     Avalanche   quote.USD.percent_change_1h  -0.80096
# 67     Avalanche  quote.USD.percent_change_24h   1.16910
# 68     Avalanche   quote.USD.percent_change_7d -17.90506
# 69     Avalanche  quote.USD.percent_change_30d  -5.89832
# 70     Avalanche  quote.USD.percent_change_60d -32.82681
# 71     Avalanche  quote.USD.percent_change_90d -36.06750
# 72     Shiba Inu   quote.USD.percent_change_1h  -0.23909
# 73     Shiba Inu  quote.USD.percent_change_24h  -0.32722
# 74     Shiba Inu   quote.USD.percent_change_7d -14.41825
# 75     Shiba Inu  quote.USD.percent_change_30d  -1.71600
# 76     Shiba Inu  quote.USD.percent_change_60d -38.90892
# 77     Shiba Inu  quote.USD.percent_change_90d -40.73730
# 78      Polkadot   quote.USD.percent_change_1h  -0.50993
# 79      Polkadot  quote.USD.percent_change_24h   2.40823
# 80      Polkadot   quote.USD.percent_change_7d -11.78612
# 81      Polkadot  quote.USD.percent_change_30d -10.33906
# 82      Polkadot  quote.USD.percent_change_60d -27.84348
# 83      Polkadot  quote.USD.percent_change_90d -28.29764
# 84  Bitcoin Cash   quote.USD.percent_change_1h  -0.47528
# 85  Bitcoin Cash  quote.USD.percent_change_24h  -3.39906
# 86  Bitcoin Cash   quote.USD.percent_change_7d  -4.05295
# 87  Bitcoin Cash  quote.USD.percent_change_30d  10.30627
# 88  Bitcoin Cash  quote.USD.percent_change_60d -19.85775
# 89  Bitcoin Cash  quote.USD.percent_change_90d -19.24750

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h' , 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#             name percent_change    values
# 0        Bitcoin             1h  -0.23919
# 1        Bitcoin            24h  -1.60619
# 2        Bitcoin             7d -10.09599
# 3        Bitcoin            30d   7.62232
# 4        Bitcoin            60d -11.51947
# 5        Bitcoin            90d  -3.56586
# 6       Ethereum             1h  -0.31745
# 7       Ethereum            24h  -0.05870
# 8       Ethereum             7d  -8.98447
# 9       Ethereum            30d  -3.96185
# 10      Ethereum            60d -20.96424
# 11      Ethereum            90d  -4.99493
# 12   Tether USDt             1h   0.00411
# 13   Tether USDt            24h   0.04678
# 14   Tether USDt             7d  -0.07110
# 15   Tether USDt            30d  -0.02748
# 16   Tether USDt            60d  -0.05931
# 17   Tether USDt            90d  -0.07831
# 18           BNB             1h  -0.13946
# 19           BNB            24h  -1.51053
# 20           BNB             7d  -7.53501
# 21           BNB            30d   3.95554
# 22           BNB            60d -17.90638
# 23           BNB            90d  -8.38227
# 24        Solana             1h  -0.43112
# 25        Solana            24h  -2.12157
# 26        Solana             7d -17.53748
# 27        Solana            30d  12.41455
# 28        Solana            60d  -8.92555
# 29        Solana            90d   2.55217
# 30          USDC             1h   0.00783
# 31          USDC            24h   0.01652
# 32          USDC             7d   0.00179
# 33          USDC            30d  -0.04594
# 34          USDC            60d  -0.03259
# 35          USDC            90d   0.00143
# 36           XRP             1h  -0.67692
# 37           XRP            24h   2.69544
# 38           XRP             7d  -5.24464
# 39           XRP            30d  27.37766
# 40           XRP            60d   7.34141
# 41           XRP            90d   6.96890
# 42      Dogecoin             1h  -0.29626
# 43      Dogecoin            24h   1.81550
# 44      Dogecoin             7d -16.00509
# 45      Dogecoin            30d   4.22205
# 46      Dogecoin            60d -29.02507
# 47      Dogecoin            90d -29.63259
# 48       Toncoin             1h  -0.14831
# 49       Toncoin            24h  -4.24505
# 50       Toncoin             7d  -8.16359
# 51       Toncoin            30d -14.72949
# 52       Toncoin            60d -12.18985
# 53       Toncoin            90d   4.05118
# 54       Cardano             1h  -0.39495
# 55       Cardano            24h   2.02375
# 56       Cardano             7d -12.90318
# 57       Cardano            30d  -3.70911
# 58       Cardano            60d -19.65179
# 59       Cardano            90d -20.31735
# 60          TRON             1h  -0.07678
# 61          TRON            24h   0.61149
# 62          TRON             7d  -8.87992
# 63          TRON            30d  -0.72536
# 64          TRON            60d   9.60042
# 65          TRON            90d   3.11271
# 66     Avalanche             1h  -0.80096
# 67     Avalanche            24h   1.16910
# 68     Avalanche             7d -17.90506
# 69     Avalanche            30d  -5.89832
# 70     Avalanche            60d -32.82681
# 71     Avalanche            90d -36.06750
# 72     Shiba Inu             1h  -0.23909
# 73     Shiba Inu            24h  -0.32722
# 74     Shiba Inu             7d -14.41825
# 75     Shiba Inu            30d  -1.71600
# 76     Shiba Inu            60d -38.90892
# 77     Shiba Inu            90d -40.73730
# 78      Polkadot             1h  -0.50993
# 79      Polkadot            24h   2.40823
# 80      Polkadot             7d -11.78612
# 81      Polkadot            30d -10.33906
# 82      Polkadot            60d -27.84348
# 83      Polkadot            90d -28.29764
# 84  Bitcoin Cash             1h  -0.47528
# 85  Bitcoin Cash            24h  -3.39906
# 86  Bitcoin Cash             7d  -4.05295
# 87  Bitcoin Cash            30d  10.30627
# 88  Bitcoin Cash            60d -19.85775
# 89  Bitcoin Cash            90d -19.24750

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x = 'percent_change', y = 'values', data = df7, kind = 'point')

# %%
df10 = df[['name', 'quote.USD.price', 'timestamp']]
df10 = df10.query("name == 'Bitcoin'") 
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      61320.86418 2024-08-03 15:44:29.894944
# 0  Bitcoin      61320.86418                        NaT

# %%
sns.set_theme(style = "darkgrid")
sns.lineplot(x = 'timestamp', y = 'quote.USD.price', data = df10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20640/1956521321.py in <module>
#       1 sns.set_theme(style = "darkgrid")
# ----> 2 sns.lineplot(x = 'timestamp', y = 'quote.USD.price', data = df10)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_single_block(self, indexer, value, name)
#    1957             # setting for extensionarrays that store dicts. Need to decide
#    1958             # if it's worth supporting that.
# -> 1959             value = self._align_series(indexer, Series(value))
#    1960
#    1961         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094             # series, so need to broadcast (see GH5206)
#    2095             if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4837
#    4838             axis = self._get_axis_number(a)
# -> 4839             obj = obj._reindex_with_indexers(
#    4840                 {axis: [new_index, indexer]},
#    4841                 fill_value=fill_value,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis
